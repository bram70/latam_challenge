# %% [markdown]
# En este archivo puedes escribir lo que estimes conveniente. Te recomendamos detallar tu solución y todas las suposiciones que estás considerando. Aquí puedes ejecutar las funciones que definiste en los otros archivos de la carpeta src, medir el tiempo, memoria, etc.

# %%
import q1_time
file_path = "/farmers-protest-tweets-2021-2-4.json"

# %timeit q1_time.q1_time(file_path)
# %load_ext memory_profiler
# %memit q1_time.q1_time(file_path)
# Out:
# 5.29 s ± 84.9 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)
# peak memory: 2415.53 MiB, increment: 1491.52 MiB

# %%
import q1_memory

file_path = "/farmers-protest-tweets-2021-2-4.json"

# %timeit q1_memory.q1_memory(file_path)
# %load_ext memory_profiler
# %memit q1_memory.q1_memory(file_path)
# Out:
# MEMORY BEFORE:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 117407 entries, 0 to 117406
# Data columns (total 21 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   url              117407 non-null  object
#  1   date             117407 non-null  datetime64[ns, UTC]
#  2   content          117407 non-null  object
#  3   renderedContent  117407 non-null  object
#  4   id               117407 non-null  int64
#  5   user             117407 non-null  object
#  6   outlinks         117407 non-null  object
#  7   tcooutlinks      117407 non-null  object
#  8   replyCount       117407 non-null  int64
#  9   retweetCount     117407 non-null  int64
#  10  likeCount        117407 non-null  int64
#  11  quoteCount       117407 non-null  int64
#  12  conversationId   117407 non-null  int64
#  13  lang             117407 non-null  object
#  14  source           117407 non-null  object
#  15  sourceUrl        116495 non-null  object
#  16  sourceLabel      116495 non-null  object
#  17  media            28109 non-null   object
#  18  retweetedTweet   0 non-null       float64
#  19  quotedTweet      41436 non-null   object
#  20  mentionedUsers   38034 non-null   object
# dtypes: datetime64[ns, UTC](1), float64(1), int64(6), object(13)
# memory usage: 266.0 MB
# MEMORY AFTER:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 117407 entries, 0 to 117406
# Data columns (total 21 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   url              117407 non-null  object
#  1   date             117407 non-null  datetime64[ns, UTC]
#  2   content          117407 non-null  object
#  3   renderedContent  117407 non-null  object
#  4   id               117407 non-null  int16
#  5   user             117407 non-null  object
#  6   outlinks         117407 non-null  object
#  7   tcooutlinks      117407 non-null  object
#  8   replyCount       117407 non-null  int16
#  9   retweetCount     117407 non-null  int16
#  10  likeCount        117407 non-null  int16
#  11  quoteCount       117407 non-null  int16
#  12  conversationId   117407 non-null  int16
#  13  lang             117407 non-null  object
#  14  source           117407 non-null  object
#  15  sourceUrl        116495 non-null  object
#  16  sourceLabel      116495 non-null  object
#  17  media            28109 non-null   object
#  18  retweetedTweet   0 non-null       float16
#  19  quotedTweet      41436 non-null   object
#  20  mentionedUsers   38034 non-null   object
# dtypes: datetime64[ns, UTC](1), float16(1), int16(6), object(13)
# memory usage: 261.3 MB
# MEMORY AFTER REMOVING EXTRA DICT DATA:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 117407 entries, 0 to 117406
# Data columns (total 23 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   date              117407 non-null  datetime64[ns, UTC]
#  1   user              117407 non-null  object
#  2   username          117407 non-null  object
#  3   displayname       117407 non-null  object
#  4   id                117407 non-null  int64
#  5   description       117407 non-null  object
#  6   rawDescription    117407 non-null  object
#  7   descriptionUrls   117407 non-null  object
#  8   verified          117407 non-null  bool
#  9   created           117407 non-null  object
#  10  followersCount    117407 non-null  int64
#  11  friendsCount      117407 non-null  int64
#  12  statusesCount     117407 non-null  int64
#  13  favouritesCount   117407 non-null  int64
#  14  listedCount       117407 non-null  int64
#  15  mediaCount        117407 non-null  int64
#  16  location          117407 non-null  object
#  17  protected         117407 non-null  bool
#  18  linkUrl           18946 non-null   object
#  19  linkTcourl        18946 non-null   object
#  20  profileImageUrl   117407 non-null  object
#  21  profileBannerUrl  78874 non-null   object
#  22  url               117407 non-null  object
# dtypes: bool(2), datetime64[ns, UTC](1), int64(7), object(13)
# memory usage: 205.4 MB
# MEMORY BEFORE:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 117407 entries, 0 to 117406
# Data columns (total 21 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   url              117407 non-null  object
#  1   date             117407 non-null  datetime64[ns, UTC]
#  2   content          117407 non-null  object
#  3   renderedContent  117407 non-null  object
#  4   id               117407 non-null  int64
#  5   user             117407 non-null  object
#  6   outlinks         117407 non-null  object
#  7   tcooutlinks      117407 non-null  object
#  8   replyCount       117407 non-null  int64
#  9   retweetCount     117407 non-null  int64
#  10  likeCount        117407 non-null  int64
#  11  quoteCount       117407 non-null  int64
#  12  conversationId   117407 non-null  int64
#  13  lang             117407 non-null  object
#  14  source           117407 non-null  object
#  15  sourceUrl        116495 non-null  object
#  16  sourceLabel      116495 non-null  object
#  17  media            28109 non-null   object
#  18  retweetedTweet   0 non-null       float64
#  19  quotedTweet      41436 non-null   object
#  20  mentionedUsers   38034 non-null   object
# dtypes: datetime64[ns, UTC](1), float64(1), int64(6), object(13)
# memory usage: 266.0 MB
# MEMORY AFTER:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 117407 entries, 0 to 117406
# Data columns (total 21 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   url              117407 non-null  object
#  1   date             117407 non-null  datetime64[ns, UTC]
#  2   content          117407 non-null  object
#  3   renderedContent  117407 non-null  object
#  4   id               117407 non-null  int16
#  5   user             117407 non-null  object
#  6   outlinks         117407 non-null  object
#  7   tcooutlinks      117407 non-null  object
#  8   replyCount       117407 non-null  int16
#  9   retweetCount     117407 non-null  int16
#  10  likeCount        117407 non-null  int16
#  11  quoteCount       117407 non-null  int16
#  12  conversationId   117407 non-null  int16
#  13  lang             117407 non-null  object
#  14  source           117407 non-null  object
#  15  sourceUrl        116495 non-null  object
#  16  sourceLabel      116495 non-null  object
#  17  media            28109 non-null   object
#  18  retweetedTweet   0 non-null       float16
#  19  quotedTweet      41436 non-null   object
#  20  mentionedUsers   38034 non-null   object
# dtypes: datetime64[ns, UTC](1), float16(1), int16(6), object(13)
# memory usage: 261.3 MB
# MEMORY AFTER REMOVING EXTRA DICT DATA:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 117407 entries, 0 to 117406
# Data columns (total 23 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   date              117407 non-null  datetime64[ns, UTC]
#  1   user              117407 non-null  object
#  2   username          117407 non-null  object
#  3   displayname       117407 non-null  object
#  4   id                117407 non-null  int64
#  5   description       117407 non-null  object
#  6   rawDescription    117407 non-null  object
#  7   descriptionUrls   117407 non-null  object
#  8   verified          117407 non-null  bool
#  9   created           117407 non-null  object
#  10  followersCount    117407 non-null  int64
#  11  friendsCount      117407 non-null  int64
#  12  statusesCount     117407 non-null  int64
#  13  favouritesCount   117407 non-null  int64
#  14  listedCount       117407 non-null  int64
#  15  mediaCount        117407 non-null  int64
#  16  location          117407 non-null  object
#  17  protected         117407 non-null  bool
#  18  linkUrl           18946 non-null   object
#  19  linkTcourl        18946 non-null   object
#  20  profileImageUrl   117407 non-null  object
#  21  profileBannerUrl  78874 non-null   object
#  22  url               117407 non-null  object
# dtypes: bool(2), datetime64[ns, UTC](1), int64(7), object(13)
# memory usage: 205.4 MB
# MEMORY BEFORE:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 117407 entries, 0 to 117406
# Data columns (total 21 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   url              117407 non-null  object
#  1   date             117407 non-null  datetime64[ns, UTC]
#  2   content          117407 non-null  object
#  3   renderedContent  117407 non-null  object
#  4   id               117407 non-null  int64
#  5   user             117407 non-null  object
#  6   outlinks         117407 non-null  object
#  7   tcooutlinks      117407 non-null  object
#  8   replyCount       117407 non-null  int64
#  9   retweetCount     117407 non-null  int64
#  10  likeCount        117407 non-null  int64
#  11  quoteCount       117407 non-null  int64
#  12  conversationId   117407 non-null  int64
#  13  lang             117407 non-null  object
#  14  source           117407 non-null  object
#  15  sourceUrl        116495 non-null  object
#  16  sourceLabel      116495 non-null  object
#  17  media            28109 non-null   object
#  18  retweetedTweet   0 non-null       float64
#  19  quotedTweet      41436 non-null   object
#  20  mentionedUsers   38034 non-null   object
# dtypes: datetime64[ns, UTC](1), float64(1), int64(6), object(13)
# memory usage: 266.0 MB
# MEMORY AFTER:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 117407 entries, 0 to 117406
# Data columns (total 21 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   url              117407 non-null  object
#  1   date             117407 non-null  datetime64[ns, UTC]
#  2   content          117407 non-null  object
#  3   renderedContent  117407 non-null  object
#  4   id               117407 non-null  int16
#  5   user             117407 non-null  object
#  6   outlinks         117407 non-null  object
#  7   tcooutlinks      117407 non-null  object
#  8   replyCount       117407 non-null  int16
#  9   retweetCount     117407 non-null  int16
#  10  likeCount        117407 non-null  int16
#  11  quoteCount       117407 non-null  int16
#  12  conversationId   117407 non-null  int16
#  13  lang             117407 non-null  object
#  14  source           117407 non-null  object
#  15  sourceUrl        116495 non-null  object
#  16  sourceLabel      116495 non-null  object
#  17  media            28109 non-null   object
#  18  retweetedTweet   0 non-null       float16
#  19  quotedTweet      41436 non-null   object
#  20  mentionedUsers   38034 non-null   object
# dtypes: datetime64[ns, UTC](1), float16(1), int16(6), object(13)
# memory usage: 261.3 MB
# MEMORY AFTER REMOVING EXTRA DICT DATA:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 117407 entries, 0 to 117406
# Data columns (total 23 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   date              117407 non-null  datetime64[ns, UTC]
#  1   user              117407 non-null  object
#  2   username          117407 non-null  object
#  3   displayname       117407 non-null  object
#  4   id                117407 non-null  int64
#  5   description       117407 non-null  object
#  6   rawDescription    117407 non-null  object
#  7   descriptionUrls   117407 non-null  object
#  8   verified          117407 non-null  bool
#  9   created           117407 non-null  object
#  10  followersCount    117407 non-null  int64
#  11  friendsCount      117407 non-null  int64
#  12  statusesCount     117407 non-null  int64
#  13  favouritesCount   117407 non-null  int64
#  14  listedCount       117407 non-null  int64
#  15  mediaCount        117407 non-null  int64
#  16  location          117407 non-null  object
#  17  protected         117407 non-null  bool
#  18  linkUrl           18946 non-null   object
#  19  linkTcourl        18946 non-null   object
#  20  profileImageUrl   117407 non-null  object
#  21  profileBannerUrl  78874 non-null   object
#  22  url               117407 non-null  object
# dtypes: bool(2), datetime64[ns, UTC](1), int64(7), object(13)
# memory usage: 205.4 MB
# MEMORY BEFORE:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 117407 entries, 0 to 117406
# Data columns (total 21 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   url              117407 non-null  object
#  1   date             117407 non-null  datetime64[ns, UTC]
#  2   content          117407 non-null  object
#  3   renderedContent  117407 non-null  object
#  4   id               117407 non-null  int64
#  5   user             117407 non-null  object
#  6   outlinks         117407 non-null  object
#  7   tcooutlinks      117407 non-null  object
#  8   replyCount       117407 non-null  int64
#  9   retweetCount     117407 non-null  int64
#  10  likeCount        117407 non-null  int64
#  11  quoteCount       117407 non-null  int64
#  12  conversationId   117407 non-null  int64
#  13  lang             117407 non-null  object
#  14  source           117407 non-null  object
#  15  sourceUrl        116495 non-null  object
#  16  sourceLabel      116495 non-null  object
#  17  media            28109 non-null   object
#  18  retweetedTweet   0 non-null       float64
#  19  quotedTweet      41436 non-null   object
#  20  mentionedUsers   38034 non-null   object
# dtypes: datetime64[ns, UTC](1), float64(1), int64(6), object(13)
# memory usage: 266.0 MB
# MEMORY AFTER:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 117407 entries, 0 to 117406
# Data columns (total 21 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   url              117407 non-null  object
#  1   date             117407 non-null  datetime64[ns, UTC]
#  2   content          117407 non-null  object
#  3   renderedContent  117407 non-null  object
#  4   id               117407 non-null  int16
#  5   user             117407 non-null  object
#  6   outlinks         117407 non-null  object
#  7   tcooutlinks      117407 non-null  object
#  8   replyCount       117407 non-null  int16
#  9   retweetCount     117407 non-null  int16
#  10  likeCount        117407 non-null  int16
#  11  quoteCount       117407 non-null  int16
#  12  conversationId   117407 non-null  int16
#  13  lang             117407 non-null  object
#  14  source           117407 non-null  object
#  15  sourceUrl        116495 non-null  object
#  16  sourceLabel      116495 non-null  object
#  17  media            28109 non-null   object
#  18  retweetedTweet   0 non-null       float16
#  19  quotedTweet      41436 non-null   object
#  20  mentionedUsers   38034 non-null   object
# dtypes: datetime64[ns, UTC](1), float16(1), int16(6), object(13)
# memory usage: 261.3 MB
# MEMORY AFTER REMOVING EXTRA DICT DATA:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 117407 entries, 0 to 117406
# Data columns (total 23 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   date              117407 non-null  datetime64[ns, UTC]
#  1   user              117407 non-null  object
#  2   username          117407 non-null  object
#  3   displayname       117407 non-null  object
#  4   id                117407 non-null  int64
#  5   description       117407 non-null  object
#  6   rawDescription    117407 non-null  object
#  7   descriptionUrls   117407 non-null  object
#  8   verified          117407 non-null  bool
#  9   created           117407 non-null  object
#  10  followersCount    117407 non-null  int64
#  11  friendsCount      117407 non-null  int64
#  12  statusesCount     117407 non-null  int64
#  13  favouritesCount   117407 non-null  int64
#  14  listedCount       117407 non-null  int64
#  15  mediaCount        117407 non-null  int64
#  16  location          117407 non-null  object
#  17  protected         117407 non-null  bool
#  18  linkUrl           18946 non-null   object
#  19  linkTcourl        18946 non-null   object
#  20  profileImageUrl   117407 non-null  object
#  21  profileBannerUrl  78874 non-null   object
#  22  url               117407 non-null  object
# dtypes: bool(2), datetime64[ns, UTC](1), int64(7), object(13)
# memory usage: 205.4 MB
# MEMORY BEFORE:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 117407 entries, 0 to 117406
# Data columns (total 21 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   url              117407 non-null  object
#  1   date             117407 non-null  datetime64[ns, UTC]
#  2   content          117407 non-null  object
#  3   renderedContent  117407 non-null  object
#  4   id               117407 non-null  int64
#  5   user             117407 non-null  object
#  6   outlinks         117407 non-null  object
#  7   tcooutlinks      117407 non-null  object
#  8   replyCount       117407 non-null  int64
#  9   retweetCount     117407 non-null  int64
#  10  likeCount        117407 non-null  int64
#  11  quoteCount       117407 non-null  int64
#  12  conversationId   117407 non-null  int64
#  13  lang             117407 non-null  object
#  14  source           117407 non-null  object
#  15  sourceUrl        116495 non-null  object
#  16  sourceLabel      116495 non-null  object
#  17  media            28109 non-null   object
#  18  retweetedTweet   0 non-null       float64
#  19  quotedTweet      41436 non-null   object
#  20  mentionedUsers   38034 non-null   object
# dtypes: datetime64[ns, UTC](1), float64(1), int64(6), object(13)
# memory usage: 266.0 MB
# MEMORY AFTER:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 117407 entries, 0 to 117406
# Data columns (total 21 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   url              117407 non-null  object
#  1   date             117407 non-null  datetime64[ns, UTC]
#  2   content          117407 non-null  object
#  3   renderedContent  117407 non-null  object
#  4   id               117407 non-null  int16
#  5   user             117407 non-null  object
#  6   outlinks         117407 non-null  object
#  7   tcooutlinks      117407 non-null  object
#  8   replyCount       117407 non-null  int16
#  9   retweetCount     117407 non-null  int16
#  10  likeCount        117407 non-null  int16
#  11  quoteCount       117407 non-null  int16
#  12  conversationId   117407 non-null  int16
#  13  lang             117407 non-null  object
#  14  source           117407 non-null  object
#  15  sourceUrl        116495 non-null  object
#  16  sourceLabel      116495 non-null  object
#  17  media            28109 non-null   object
#  18  retweetedTweet   0 non-null       float16
#  19  quotedTweet      41436 non-null   object
#  20  mentionedUsers   38034 non-null   object
# dtypes: datetime64[ns, UTC](1), float16(1), int16(6), object(13)
# memory usage: 261.3 MB
# MEMORY AFTER REMOVING EXTRA DICT DATA:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 117407 entries, 0 to 117406
# Data columns (total 23 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   date              117407 non-null  datetime64[ns, UTC]
#  1   user              117407 non-null  object
#  2   username          117407 non-null  object
#  3   displayname       117407 non-null  object
#  4   id                117407 non-null  int64
#  5   description       117407 non-null  object
#  6   rawDescription    117407 non-null  object
#  7   descriptionUrls   117407 non-null  object
#  8   verified          117407 non-null  bool
#  9   created           117407 non-null  object
#  10  followersCount    117407 non-null  int64
#  11  friendsCount      117407 non-null  int64
#  12  statusesCount     117407 non-null  int64
#  13  favouritesCount   117407 non-null  int64
#  14  listedCount       117407 non-null  int64
#  15  mediaCount        117407 non-null  int64
#  16  location          117407 non-null  object
#  17  protected         117407 non-null  bool
#  18  linkUrl           18946 non-null   object
#  19  linkTcourl        18946 non-null   object
#  20  profileImageUrl   117407 non-null  object
#  21  profileBannerUrl  78874 non-null   object
#  22  url               117407 non-null  object
# dtypes: bool(2), datetime64[ns, UTC](1), int64(7), object(13)
# memory usage: 205.4 MB
# MEMORY BEFORE:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 117407 entries, 0 to 117406
# Data columns (total 21 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   url              117407 non-null  object
#  1   date             117407 non-null  datetime64[ns, UTC]
#  2   content          117407 non-null  object
#  3   renderedContent  117407 non-null  object
#  4   id               117407 non-null  int64
#  5   user             117407 non-null  object
#  6   outlinks         117407 non-null  object
#  7   tcooutlinks      117407 non-null  object
#  8   replyCount       117407 non-null  int64
#  9   retweetCount     117407 non-null  int64
#  10  likeCount        117407 non-null  int64
#  11  quoteCount       117407 non-null  int64
#  12  conversationId   117407 non-null  int64
#  13  lang             117407 non-null  object
#  14  source           117407 non-null  object
#  15  sourceUrl        116495 non-null  object
#  16  sourceLabel      116495 non-null  object
#  17  media            28109 non-null   object
#  18  retweetedTweet   0 non-null       float64
#  19  quotedTweet      41436 non-null   object
#  20  mentionedUsers   38034 non-null   object
# dtypes: datetime64[ns, UTC](1), float64(1), int64(6), object(13)
# memory usage: 266.0 MB
# MEMORY AFTER:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 117407 entries, 0 to 117406
# Data columns (total 21 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   url              117407 non-null  object
#  1   date             117407 non-null  datetime64[ns, UTC]
#  2   content          117407 non-null  object
#  3   renderedContent  117407 non-null  object
#  4   id               117407 non-null  int16
#  5   user             117407 non-null  object
#  6   outlinks         117407 non-null  object
#  7   tcooutlinks      117407 non-null  object
#  8   replyCount       117407 non-null  int16
#  9   retweetCount     117407 non-null  int16
#  10  likeCount        117407 non-null  int16
#  11  quoteCount       117407 non-null  int16
#  12  conversationId   117407 non-null  int16
#  13  lang             117407 non-null  object
#  14  source           117407 non-null  object
#  15  sourceUrl        116495 non-null  object
#  16  sourceLabel      116495 non-null  object
#  17  media            28109 non-null   object
#  18  retweetedTweet   0 non-null       float16
#  19  quotedTweet      41436 non-null   object
#  20  mentionedUsers   38034 non-null   object
# dtypes: datetime64[ns, UTC](1), float16(1), int16(6), object(13)
# memory usage: 261.3 MB
# MEMORY AFTER REMOVING EXTRA DICT DATA:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 117407 entries, 0 to 117406
# Data columns (total 23 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   date              117407 non-null  datetime64[ns, UTC]
#  1   user              117407 non-null  object
#  2   username          117407 non-null  object
#  3   displayname       117407 non-null  object
#  4   id                117407 non-null  int64
#  5   description       117407 non-null  object
#  6   rawDescription    117407 non-null  object
#  7   descriptionUrls   117407 non-null  object
#  8   verified          117407 non-null  bool
#  9   created           117407 non-null  object
#  10  followersCount    117407 non-null  int64
#  11  friendsCount      117407 non-null  int64
#  12  statusesCount     117407 non-null  int64
#  13  favouritesCount   117407 non-null  int64
#  14  listedCount       117407 non-null  int64
#  15  mediaCount        117407 non-null  int64
#  16  location          117407 non-null  object
#  17  protected         117407 non-null  bool
#  18  linkUrl           18946 non-null   object
#  19  linkTcourl        18946 non-null   object
#  20  profileImageUrl   117407 non-null  object
#  21  profileBannerUrl  78874 non-null   object
#  22  url               117407 non-null  object
# dtypes: bool(2), datetime64[ns, UTC](1), int64(7), object(13)
# memory usage: 205.4 MB
# MEMORY BEFORE:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 117407 entries, 0 to 117406
# Data columns (total 21 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   url              117407 non-null  object
#  1   date             117407 non-null  datetime64[ns, UTC]
#  2   content          117407 non-null  object
#  3   renderedContent  117407 non-null  object
#  4   id               117407 non-null  int64
#  5   user             117407 non-null  object
#  6   outlinks         117407 non-null  object
#  7   tcooutlinks      117407 non-null  object
#  8   replyCount       117407 non-null  int64
#  9   retweetCount     117407 non-null  int64
#  10  likeCount        117407 non-null  int64
#  11  quoteCount       117407 non-null  int64
#  12  conversationId   117407 non-null  int64
#  13  lang             117407 non-null  object
#  14  source           117407 non-null  object
#  15  sourceUrl        116495 non-null  object
#  16  sourceLabel      116495 non-null  object
#  17  media            28109 non-null   object
#  18  retweetedTweet   0 non-null       float64
#  19  quotedTweet      41436 non-null   object
#  20  mentionedUsers   38034 non-null   object
# dtypes: datetime64[ns, UTC](1), float64(1), int64(6), object(13)
# memory usage: 266.0 MB
# MEMORY AFTER:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 117407 entries, 0 to 117406
# Data columns (total 21 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   url              117407 non-null  object
#  1   date             117407 non-null  datetime64[ns, UTC]
#  2   content          117407 non-null  object
#  3   renderedContent  117407 non-null  object
#  4   id               117407 non-null  int16
#  5   user             117407 non-null  object
#  6   outlinks         117407 non-null  object
#  7   tcooutlinks      117407 non-null  object
#  8   replyCount       117407 non-null  int16
#  9   retweetCount     117407 non-null  int16
#  10  likeCount        117407 non-null  int16
#  11  quoteCount       117407 non-null  int16
#  12  conversationId   117407 non-null  int16
#  13  lang             117407 non-null  object
#  14  source           117407 non-null  object
#  15  sourceUrl        116495 non-null  object
#  16  sourceLabel      116495 non-null  object
#  17  media            28109 non-null   object
#  18  retweetedTweet   0 non-null       float16
#  19  quotedTweet      41436 non-null   object
#  20  mentionedUsers   38034 non-null   object
# dtypes: datetime64[ns, UTC](1), float16(1), int16(6), object(13)
# memory usage: 261.3 MB
# MEMORY AFTER REMOVING EXTRA DICT DATA:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 117407 entries, 0 to 117406
# Data columns (total 23 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   date              117407 non-null  datetime64[ns, UTC]
#  1   user              117407 non-null  object
#  2   username          117407 non-null  object
#  3   displayname       117407 non-null  object
#  4   id                117407 non-null  int64
#  5   description       117407 non-null  object
#  6   rawDescription    117407 non-null  object
#  7   descriptionUrls   117407 non-null  object
#  8   verified          117407 non-null  bool
#  9   created           117407 non-null  object
#  10  followersCount    117407 non-null  int64
#  11  friendsCount      117407 non-null  int64
#  12  statusesCount     117407 non-null  int64
#  13  favouritesCount   117407 non-null  int64
#  14  listedCount       117407 non-null  int64
#  15  mediaCount        117407 non-null  int64
#  16  location          117407 non-null  object
#  17  protected         117407 non-null  bool
#  18  linkUrl           18946 non-null   object
#  19  linkTcourl        18946 non-null   object
#  20  profileImageUrl   117407 non-null  object
#  21  profileBannerUrl  78874 non-null   object
#  22  url               117407 non-null  object
# dtypes: bool(2), datetime64[ns, UTC](1), int64(7), object(13)
# memory usage: 205.4 MB
# MEMORY BEFORE:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 117407 entries, 0 to 117406
# Data columns (total 21 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   url              117407 non-null  object
#  1   date             117407 non-null  datetime64[ns, UTC]
#  2   content          117407 non-null  object
#  3   renderedContent  117407 non-null  object
#  4   id               117407 non-null  int64
#  5   user             117407 non-null  object
#  6   outlinks         117407 non-null  object
#  7   tcooutlinks      117407 non-null  object
#  8   replyCount       117407 non-null  int64
#  9   retweetCount     117407 non-null  int64
#  10  likeCount        117407 non-null  int64
#  11  quoteCount       117407 non-null  int64
#  12  conversationId   117407 non-null  int64
#  13  lang             117407 non-null  object
#  14  source           117407 non-null  object
#  15  sourceUrl        116495 non-null  object
#  16  sourceLabel      116495 non-null  object
#  17  media            28109 non-null   object
#  18  retweetedTweet   0 non-null       float64
#  19  quotedTweet      41436 non-null   object
#  20  mentionedUsers   38034 non-null   object
# dtypes: datetime64[ns, UTC](1), float64(1), int64(6), object(13)
# memory usage: 266.0 MB
# MEMORY AFTER:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 117407 entries, 0 to 117406
# Data columns (total 21 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   url              117407 non-null  object
#  1   date             117407 non-null  datetime64[ns, UTC]
#  2   content          117407 non-null  object
#  3   renderedContent  117407 non-null  object
#  4   id               117407 non-null  int16
#  5   user             117407 non-null  object
#  6   outlinks         117407 non-null  object
#  7   tcooutlinks      117407 non-null  object
#  8   replyCount       117407 non-null  int16
#  9   retweetCount     117407 non-null  int16
#  10  likeCount        117407 non-null  int16
#  11  quoteCount       117407 non-null  int16
#  12  conversationId   117407 non-null  int16
#  13  lang             117407 non-null  object
#  14  source           117407 non-null  object
#  15  sourceUrl        116495 non-null  object
#  16  sourceLabel      116495 non-null  object
#  17  media            28109 non-null   object
#  18  retweetedTweet   0 non-null       float16
#  19  quotedTweet      41436 non-null   object
#  20  mentionedUsers   38034 non-null   object
# dtypes: datetime64[ns, UTC](1), float16(1), int16(6), object(13)
# memory usage: 261.3 MB
# MEMORY AFTER REMOVING EXTRA DICT DATA:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 117407 entries, 0 to 117406
# Data columns (total 23 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   date              117407 non-null  datetime64[ns, UTC]
#  1   user              117407 non-null  object
#  2   username          117407 non-null  object
#  3   displayname       117407 non-null  object
#  4   id                117407 non-null  int64
#  5   description       117407 non-null  object
#  6   rawDescription    117407 non-null  object
#  7   descriptionUrls   117407 non-null  object
#  8   verified          117407 non-null  bool
#  9   created           117407 non-null  object
#  10  followersCount    117407 non-null  int64
#  11  friendsCount      117407 non-null  int64
#  12  statusesCount     117407 non-null  int64
#  13  favouritesCount   117407 non-null  int64
#  14  listedCount       117407 non-null  int64
#  15  mediaCount        117407 non-null  int64
#  16  location          117407 non-null  object
#  17  protected         117407 non-null  bool
#  18  linkUrl           18946 non-null   object
#  19  linkTcourl        18946 non-null   object
#  20  profileImageUrl   117407 non-null  object
#  21  profileBannerUrl  78874 non-null   object
#  22  url               117407 non-null  object
# dtypes: bool(2), datetime64[ns, UTC](1), int64(7), object(13)
# memory usage: 205.4 MB
# 17.1 s ± 134 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)
# MEMORY BEFORE:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 117407 entries, 0 to 117406
# Data columns (total 21 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   url              117407 non-null  object
#  1   date             117407 non-null  datetime64[ns, UTC]
#  2   content          117407 non-null  object
#  3   renderedContent  117407 non-null  object
#  4   id               117407 non-null  int64
#  5   user             117407 non-null  object
#  6   outlinks         117407 non-null  object
#  7   tcooutlinks      117407 non-null  object
#  8   replyCount       117407 non-null  int64
#  9   retweetCount     117407 non-null  int64
#  10  likeCount        117407 non-null  int64
#  11  quoteCount       117407 non-null  int64
#  12  conversationId   117407 non-null  int64
#  13  lang             117407 non-null  object
#  14  source           117407 non-null  object
#  15  sourceUrl        116495 non-null  object
#  16  sourceLabel      116495 non-null  object
#  17  media            28109 non-null   object
#  18  retweetedTweet   0 non-null       float64
#  19  quotedTweet      41436 non-null   object
#  20  mentionedUsers   38034 non-null   object
# dtypes: datetime64[ns, UTC](1), float64(1), int64(6), object(13)
# memory usage: 266.0 MB
# MEMORY AFTER:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 117407 entries, 0 to 117406
# Data columns (total 21 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   url              117407 non-null  object
#  1   date             117407 non-null  datetime64[ns, UTC]
#  2   content          117407 non-null  object
#  3   renderedContent  117407 non-null  object
#  4   id               117407 non-null  int16
#  5   user             117407 non-null  object
#  6   outlinks         117407 non-null  object
#  7   tcooutlinks      117407 non-null  object
#  8   replyCount       117407 non-null  int16
#  9   retweetCount     117407 non-null  int16
#  10  likeCount        117407 non-null  int16
#  11  quoteCount       117407 non-null  int16
#  12  conversationId   117407 non-null  int16
#  13  lang             117407 non-null  object
#  14  source           117407 non-null  object
#  15  sourceUrl        116495 non-null  object
#  16  sourceLabel      116495 non-null  object
#  17  media            28109 non-null   object
#  18  retweetedTweet   0 non-null       float16
#  19  quotedTweet      41436 non-null   object
#  20  mentionedUsers   38034 non-null   object
# dtypes: datetime64[ns, UTC](1), float16(1), int16(6), object(13)
# memory usage: 261.3 MB
# MEMORY AFTER REMOVING EXTRA DICT DATA:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 117407 entries, 0 to 117406
# Data columns (total 23 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   date              117407 non-null  datetime64[ns, UTC]
#  1   user              117407 non-null  object
#  2   username          117407 non-null  object
#  3   displayname       117407 non-null  object
#  4   id                117407 non-null  int64
#  5   description       117407 non-null  object
#  6   rawDescription    117407 non-null  object
#  7   descriptionUrls   117407 non-null  object
#  8   verified          117407 non-null  bool
#  9   created           117407 non-null  object
#  10  followersCount    117407 non-null  int64
#  11  friendsCount      117407 non-null  int64
#  12  statusesCount     117407 non-null  int64
#  13  favouritesCount   117407 non-null  int64
#  14  listedCount       117407 non-null  int64
#  15  mediaCount        117407 non-null  int64
#  16  location          117407 non-null  object
#  17  protected         117407 non-null  bool
#  18  linkUrl           18946 non-null   object
#  19  linkTcourl        18946 non-null   object
#  20  profileImageUrl   117407 non-null  object
#  21  profileBannerUrl  78874 non-null   object
#  22  url               117407 non-null  object
# dtypes: bool(2), datetime64[ns, UTC](1), int64(7), object(13)
# memory usage: 205.4 MB
# peak memory: 3142.67 MiB, increment: 2294.38 MiB

# %%
import q2_time

file_path = "/farmers-protest-tweets-2021-2-4.json"

# %timeit q2_time.q2_time(file_path)
# %load_ext memory_profiler
# %memit q2_time.q2_time(file_path)
# Out:
# 8.1 s ± 44.7 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)
# peak memory: 2958.52 MiB, increment: 2578.47 MiB

# %%
import q3_time

file_path = "/farmers-protest-tweets-2021-2-4.json"

# %timeit q3_time.q3_time(file_path)
# %load_ext memory_profiler
# %memit q3_time.q3_time(file_path)
# Out:
# 2.96 s ± 424 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)
# peak memory: 3911.41 MiB, increment: 1810.25 MiB

# %%
df.info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 117407 entries, 0 to 117406
# Series name: mentionedUsers
# Non-Null Count  Dtype
# --------------  -----
# 38034 non-null  object
# dtypes: object(1)
# memory usage: 917.4+ KB

# %%
print(df.head(10))
# Out:
# 0    [{'username': 'narendramodi', 'displayname': '...
# 1    [{'username': 'Kisanektamorcha', 'displayname'...
# 2                                                 None
# 3    [{'username': 'ReallySwara', 'displayname': 'S...
# 4                                                 None
# 5                                                 None
# 6                                                 None
# 7                                                 None
# 8    [{'username': 'mandeeppunia1', 'displayname': ...
# 9                                                 None
# Name: mentionedUsers, dtype: object

# %%
df_filtered = df.dropna()
df_filtered.info()
# Out:
# <class 'pandas.core.series.Series'>
# Index: 38034 entries, 0 to 117406
# Series name: mentionedUsers
# Non-Null Count  Dtype
# --------------  -----
# 38034 non-null  object
# dtypes: object(1)
# memory usage: 594.3+ KB

# %%
df['emojis'] = df['content'].apply(lambda x: split_count(str(x)))
# Out:
# 0     [{'username': 'narendramodi', 'displayname': '...
# 1     [{'username': 'Kisanektamorcha', 'displayname'...
# 3     [{'username': 'ReallySwara', 'displayname': 'S...
# 8     [{'username': 'mandeeppunia1', 'displayname': ...
# 11    [{'username': 'mandeeppunia1', 'displayname': ...
# 16    [{'username': 'akshaykumar', 'displayname': 'A...
# 18    [{'username': 'taapsee', 'displayname': 'taaps...
# 20    [{'username': 'PetroleumMin', 'displayname': '...
# 24    [{'username': 'ArmaanMalik22', 'displayname': ...
# 26    [{'username': 'akshaykumar', 'displayname': 'A...
# Name: mentionedUsers, dtype: object

# %%
df_filtered.head(10)
usermentioned = [[str(element['username']).lower() for element in list(row)] for row in df_filtered]

# %%
usermentioned[0]
# Out:
# ['narendramodi', 'delhipolice']

# %%
from collections import Counter
new_list = Counter(x for xs in usermentioned for x in set(xs))
print(new_list.most_common(10))
# Out:
# [('narendramodi', 2217), ('kisanektamorcha', 1832), ('rakeshtikaitbku', 1615), ('pmoindia', 1404), ('rahulgandhi', 1128), ('gretathunberg', 1025), ('ravisinghka', 1009), ('unhumanrights', 955), ('rihanna', 953), ('meenaharris', 900)]

# %%
print(final_counter)
# Out:
# Counter({('narendramodi',): 680, ('kisanektamorcha',): 617, ('youtube',): 531, ('rakeshtikaitbku',): 381, ('ravisinghka',): 355, ('pmoindia',): 313, ('tractor2twitr',): 289, ('rahulgandhi',): 250, ('gretathunberg',): 229, ('delhipolice',): 224, ('punyaab',): 213, ('amaanbali',): 205, ('meenaharris',): 189, ('un', 'intlcrimcourt', 'cij_icj'): 175, ('ndtv',): 174, ('claudiawebbe',): 173, ('kanganateam',): 171, ('rihanna',): 171, ('sachin_rt',): 161, ('jazzyb',): 148, ('thewire_in',): 129, ('pmoindia', 'narendramodi'): 114, ('mandeeppunia1',): 112, ('amandacerny',): 108, ('ani',): 103, ('sherryontopp',): 100, ('monica_gill1',): 99, ('bjp4india',): 98, ('unhumanrights',): 95, ('timestrolley',): 94, ('pbhushan1',): 89, ('akshaykumar',): 88, ('saahilmenghani',): 83, ('davinder_7',): 82, ('aajtak',): 79, ('arvindkejriwal',): 78, ('volunteer4farmr',): 77, ('mssirsa',): 74, ('miakhalifa',): 74, ('bkuektaugrahan',): 71, ('mahuamoitra',): 70, ('ajitanjum',): 68, ('kisanektamorcha', 'tractor2twitr', 'ani', 'pti_news', 'officialbku', 'bbchindi', 'ndtvindia', 'ptcnews', 'dailypostpnbi', 'zeenews', 'republic', 'abpnews', 'abhayschautala', 'deependershooda', 'bhagwantmann', 'priyankagandhi', 'arvindkejriwal', 'rakeshtikaitbku'): 68, ('licypriyak',): 67, ('preetjaikaur',): 66, ('amitshah',): 64, ('jpdalalbjp',): 64, ('zeenews',): 63, ('priyankagandhi',): 62, ('sachinpilot',): 60, ('_yogendrayadav',): 58, ('nytimes',): 57, ('diljitdosanjh',): 56, ('bbcnewspunjabi', 'unhumanrights', 'hrw', 'unocha', 'amnesty', 'malala'): 56, ('reallyswara',): 53, ('reuters',): 53, ('cmohry', 'haryanapolice27'): 52, ('nstomar',): 51, ('incindia',): 50, ('indianexpress',): 48, ('syedmdrehan',): 48, ('gippygrewal',): 48, ('deependershooda',): 47, ('profdilipmandal',): 47, ('raza_akhan',): 46, ('friedrichpieter',): 46, ('tractor2twitr', 'kisanektamorcha'): 45, ('rupikaur_',): 45, ('un', 'cij_icj'): 45, ('srbachchan',): 45, ('navneet_tweets_',): 42, ('iamnavroop',): 41, ('saahilmenghani', 'saahilmenghani'): 41, ('mandy_takhar',): 41, ('mandeep_puniaa',): 40, ('ndtvindia',): 40, ('sukhdevsingh_',): 40, ('susansarandon',): 40, ('rajatsharmalive',): 39, ('sushant_says',): 39, ('bhupenderc19',): 38, ('hansrajmeena',): 37, ('dhruv_rathee',): 36, ('the_hindu',): 36, ('lambaalka',): 36, ('monikasingh__',): 35, ('narendramodi', 'bjp4india'): 35, ('gurnamsinghbku',): 35, ('priyankagandhi', 'rahulgandhi', 'incindia', 'un'): 35, ('surenderaicc', 'kisan_congress'): 33, ('potus',): 33, ('ninabhullar1',): 33, ('hrw',): 33, ('taapsee',): 32, ('timesofindia',): 32, ('kisanektamarch',): 32, ('joebiden', 'justintrudeau', 'gretathunberg', 'un', 'rihanna', 'unhumanrights'): 31, ('kanhaiyakumar',): 31, ('bjp4india', 'narendramodi'): 31, ('rustyrockets',): 31, ('piperperabo',): 31, ('thedailyshow',): 31, ('i_am_ravish',): 30, ('rohini_sgh',): 30, ('time',): 30, ('tandhesi',): 30, ('meenaharris', 'simran'): 30, ('kisan_congress', 'surenderaicc'): 29, ('chow_chow_bath', 'amaanbali'): 29, ('suryapsingh_ias',): 28, ('narendramodi', 'pmoindia'): 28, ('unhumanrights', 'hrw', 'world_affairs', 'amnesty', 'un', 'cnn'): 28, ('punjabisath1',): 27, ('jayantrld',): 27, ('kisan_congress', 'surenderaicc', 'rahulgandhi', 'nana_patole', 'kcvenugopalmp', 'priyankagandhi', 'kisan_congress', 'gilanitufail', 'simmiahuja_'): 27, ('actor_siddharth',): 27, ('imvkohli',): 26, ('imfulara',): 26, ('bawaranjit',): 26, ('smritiirani',): 25, ('baltejpannu',): 25, ('tealeoni',): 25, ('capt_amarinder',): 25, ('pti_news',): 25, ('rssurjewala',): 25, ('jagjitvaheguru',): 25, ('news24tvchannel',): 25, ('twitter',): 25, ('abpnews',): 25, ('aajtak', 'anjanaomkashyap'): 25, ('kumar31061137', 'kapilmishra_ind'): 25, ('bishnoikuldeep',): 25, ('piperperabo', 'meenaharris', 'rihanna', 'barondavis', 'licypriyak', 'jeromefosterii', 'amandacerny'): 25, ('urmilamatondkar',): 24, ('khalsaaid_india',): 24, ('arjunsethi81',): 24, ('bhagalsanju',): 24, ('khalsa_aid',): 23, ('papalpreetsingh',): 23, ('ranaayyub',): 23, ('navu061020',): 23 ...

# %%
response = emojis.explode().dropna().value_counts().sort_index(ascending=False).sort_values(ascending=False)

# %%
response = response.head(10)

# %%
from collections import Counter
tuple_response = list(response.items())

# %%
print(tuple_response)
# Out:
# [('🙏', 5049), ('😂', 3072), ('🚜', 2972), ('🌾', 2182), ('🤣', 1668), ('✊', 1642), ('❤️', 1382), ('🙏🏻', 1317), ('💚', 1040), ('👇', 873)]

# %%
# Out:
#                        date         username
# 0 2021-02-24 09:23:35+00:00  ArjunSinghPanam
# 1 2021-02-24 09:23:32+00:00       PrdeepNain
# 2 2021-02-24 09:23:22+00:00   parmarmaninder
# 3 2021-02-24 09:23:16+00:00    anmoldhaliwal
# 4 2021-02-24 09:23:10+00:00       KotiaPreet
# 5 2021-02-24 09:23:05+00:00        babli_708
# 6 2021-02-24 09:22:54+00:00  Varinde17354019
# 7 2021-02-24 09:22:35+00:00      BitnamSingh
# 8 2021-02-24 09:22:34+00:00    anmoldhaliwal
# 9 2021-02-24 09:22:11+00:00        SatThiara
